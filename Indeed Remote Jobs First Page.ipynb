# %%
import requests as rq
url= "https://www.indeed.com/jobs?q=data%20science&l=remote&vjk=262be5312bfb5498"
res= rq.get(url)

print(res)
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup as bs
jobs= bs(res.content)

# %%
results= jobs.find(id="resultsCol")
results
# Out:
# <td id="resultsCol">
# <div id="resultsColTopSpace"></div>
# <div class="messageContainer">
# <script type="text/javascript">
#       function setRefineByCookie(refineByTypes) {
#         var expires = new Date();
#         expires.setTime(expires.getTime() + (10 * 1000));
#         for (var i = 0; i < refineByTypes.length; i++) {
#           setCookie(refineByTypes[i], "1", expires);
#         }
#       }
#     </script>
# </div>
# <style type="text/css">
#     #increased_radius_result {
#         font-size: 1rem;
#         font-style: italic;
#     }
#     #original_radius_result{
#         font-size: 0.8125rem;
#         font-style: italic;
#         color: #666666;
#     }
# </style>
# ...

# %%
c_results= results.find_all("div", class_="messageContainer")
c_results
# Out:
# [<div class="messageContainer">
#  <script type="text/javascript">
#        function setRefineByCookie(refineByTypes) {
#          var expires = new Date();
#          expires.setTime(expires.getTime() + (10 * 1000));
#          for (var i = 0; i < refineByTypes.length; i++) {
#            setCookie(refineByTypes[i], "1", expires);
#          }
#        }
#      </script>
#  </div>]

# %%
c_results= results.find_all("h2", class_="jobTitle")
job_titles= [t.text.strip() for t in c_results]
job_titles
# Out:
# ['newData Analyst II',
#  'newData Science Co-Op (Fall 2022)',
#  'Analyst I/Analyst II, Data Science Underwriting Modeler',
#  'Associate, Data Science',
#  'newGraduate Data Scientist - Role Can be Remote',
#  'newQuality Control Base Data Specialist',
#  'Analyst, Revenue Data Analytics',
#  'Data Analyst (Remote)',
#  'newLead Patient Appointment Servies Specialist',
#  'Machine Learning Data Associate',
#  'newData Scientist - Operations',
#  'AI and Machine Learning Trainee (Summer 2022)',
#  'newData Scientist',
#  'Director of Data Science, Ads',
#  'Senior Director, Data Science']

# %%
import pandas as pd
df = pd.DataFrame(job_titles, columns= ["Job Title"])
df.head()
# Out:
#                                            Job Title
# 0                                 newData Analyst II
# 1                  newData Science Co-Op (Fall 2022)
# 2  Analyst I/Analyst II, Data Science Underwritin...
# 3                            Associate, Data Science
# 4    newGraduate Data Scientist - Role Can be Remote

# %%
df.to_csv("./Desktop/Indeed Remote Jobs First Page.csv")
